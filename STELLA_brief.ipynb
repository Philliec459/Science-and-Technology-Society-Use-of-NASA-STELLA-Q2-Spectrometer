# %% [markdown]
# ![image.png](attachment:d1a6ee73-3085-450f-ae5a-dfa6a5f2c70a.png)
#
#
# # Science-and-Technology-Society-Use-of-NASA-STELLA-Q2-Spectrometer
#
# The **Science and Technology Society (STS) of Sarasota-Manatee Counties, Florida** is working with the NASA STELLA (Science and Technology Education for Land/Life Assessment) outreach program as a part of our STEM initiative. According to their site,
#
# - "NASA STELLA instruments are portable low-cost do-it-yourself (DIY) instruments that support science education, and outreach through scientific engagement, inquiry, and discovery while helping you understand Landsat better".
#
# **STELLA instruments are developed under the influence and inspiration of Landsat.** This alignment not only fulfills our project needs but also serves as a compelling addition to our STEAM initiatives:
#
# 1) To train the minds young Floridians to be more aware of our wetlands, to care for them and about them.  Our program will bring more community publicity to the issue of wetlands change, as well.
#
# 2) To expose our middle- and high- school aged students to real science, using real data.  That means how to use instrumentation and understand how the data is collected, and how the data can be used in the real world.  It means not only to create beautiful charts and images that form the good results, but also to understand that data must be collected in a proper and reproducible way, that there physics reasons for lack of accuracy and lack of precision that one must understand and minimize in order to achieve meaningful results.
#
#
# The NASA STELLA-Q2 is capable of making 18 different spectral measurements from the violet/blue portions of the electromagnetic spectrum out to near infrared regions (beyond our range of vision).The following figure **(1)** shows the visible spectrum by wavelength, and the yellow box indicates the STELLA-Q2 frequency range.
#
# >![image](Spectrum.png)
#
#
# More can be found on the STELLA DIY instruments at the following link.
#
# >https://landsat.gsfc.nasa.gov/stella/
#
# The following is a sample-by-sample animation of the type of data acquired from STELLA-Q2 Spectrometer built by STS. STS is providing the python code in a Jupyter Notebook that can be used as an example of how to display the data from the STELLA-Q2 device. We have also provided some sample data to be used with this notebook. It should be noted that we did change the name of some of the headers created from our instrument to add colors to each of the wavelength reading that are made in order to display each wavelength as a corresponding color. The near infrared wavelength readings are colored in grays, wheat and gold where the normal visible spectrum colors are in vivid colors that they represent.
#
# >
# >![image](STELLA_color.gif)
# >
# ---
# ## Building the STELLA-Q2 device:
# The NASA site offers detailed instructions on how to build the STELLA-Q2 instrument at the following link:
#
# >https://landsat.gsfc.nasa.gov/stella/stella-q2/stella-q2-build-instructions/
#
# >![image](STELLA_Q2_build.png)
#
# The following image is the provided  STELLA parts list that we used to order our components. If you download the parts list file from this repository, then the links will direct you to each component from one of the two vendors.
#
# >![image](STELLA-Q2_parts_list.png)
#
# This is the STS STELLA-Q2 instrument that STS has built using the details supplied by the NASA:
#
# >![image](STELLA.jpg)
#
# ## Acknowledgment:
# We extend our heartfelt appreciation to the NASA STELLA Team for their unwavering support of our STS STELLA project. Paul Mirel, the visionary creator and lead Engineer of the STELLA project, along with Mike Taylor, the esteemed Team Leader, and Petya Campbell, the Lead Scientist, alongside all contributors to the STELLA endeavor, have been invaluable in propelling our project forward. Their provision of tools, guidance, and expertise has been instrumental in our journey. STS is profoundly grateful for their steadfast technical support, which has been pivotal in our progress.
#
# >![image](NASA_STELLA_Team.png)
#
# For more information, please go to the following website:
#
# https://landsat.gsfc.nasa.gov/stella/
#
# ---
# ## Bibliography:
# **(1)** North Carolina Geographic Information Coordinating Council by the Statewide Mapping Advisory Committee, Working Group for Orthophotography Planning, July 2011.
#
# **(2)** Charlotte Harbor National Estuary Program Technical Report 16-3, *Identifying and Diagnosing Locations of Ongoing and Future Saltwater Wetland Loss: Mangrove Heart Attack*, 3/9/2017
#
# ---
# # Testing:
# Now that we have out STELLA-Q2 device in working order, we will start our testing from know color swatches to actual vegetative species and states of health.
#
#
# ## STELLA-Q2 data
#
#
# **This is the first data from the STS STELLA-Q2 Spectrometer**
#
# ### Load Python requirments:

# %%
import altair as alt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

####import panel as pn

#pn.extension('vega')
#pn.extension('tabulator')

#####pn.extension(sizing_mode = 'stretch_width')

#######alt.data_transformers.disable_max_rows()

import re
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# ## Read in Excel data file collected on the STELLA-Q2 micro SD card:

# %%
#read the file
file = r'data.xlsx'
df = pd.read_excel(file,index_col=False)
df.head()
# Out:
#   device_type  software_version   UID   batch  weekday  timestamp_iso8601  \
# 0   STELLA-Q2             2.4.0  6858      23   Sunday   20240204T221855Z
# 1   STELLA-Q2             2.4.0  6858      23   Sunday   20240204T221856Z
# 2   STELLA-Q2             2.4.0  6858      23   Sunday   20240204T221858Z
# 3   STELLA-Q2             2.4.0  6858      23   Sunday   20240204T221859Z
# 4   STELLA-Q2             2.4.0  6858      23   Sunday   20240204T221901Z
#
#     decimal_hour   bandwidth_FWHM_nm   field_of_view_FWHM_DEG  \
# 0        22.3153                  20                       20
# 1        22.3156                  20                       20
# 2        22.3161                  20                       20
# 3        22.3164                  20                       20
# 4        22.3169                  20                       20
#
#     irradiance_410nm_purple_wavelength_nm  ...  \
# 0                                     410  ...
# 1                                     410  ...
# 2                                     410  ...
# 3                                     410  ...
# 4                                     410  ...
#
#     irradiance_900nm_wheat_wavelength_nm  \
# 0                                    900
# 1                                    900
# 2                                    900
# 3                                    900
# 4                                    900
#
#     irradiance_900nm_wheat_wavelength_uncertainty_nm  \
# 0                                                 10
# 1                                                 10
# 2                                                 10
# 3                                                 10
# 4                                                 10
#
#     irradiance_900nm_wheat_irradiance_uW_per_cm_squared  \
# 0                                              0.556
# 1                                              0.556
# 2                                              0.556
# 3                                              1.667
# 4                                              2.223
#
#     irradiance_900nm_wheat_irradiance_uncertainty_uW_per_cm_squared  \
# 0                                              0.067
# 1                                              0.067
# 2                                              0.067
# 3                                              0.200
# 4                                              0.267
#
#     irradiance_940nm_gold_wavelength_nm  \
# 0                                   940
# 1                                   940
# 2                                   940
# 3                                   940
# 4                                   940
#
#     irradiance_940nm_gold_wavelength_uncertainty_nm  \
# 0                                                10
# 1                                                10
# 2                                                10
# 3                                                10
# 4                                                10
#
#     irradiance_940nm_gold_irradiance_uW_per_cm_squared  \
# 0                                              0.000
# 1                                              0.000
# 2                                              0.882
# 3                                              0.882
# 4                                              0.882
#
#     irradiance_940nm_gold_irradiance_uncertainty_uW_per_cm_squared  \
# 0                                              0.000
# 1                                              0.000
# 2                                              0.106
# 3                                              0.106
# 4                                              0.106
#
#     battery_voltage   battery_percent
# 0              4.14                95
# 1              4.14                95
# 2              4.14                95
# 3              4.14                95
# 4              4.14                95
#
# [5 rows x 83 columns]

# %% [markdown]
# ## Explore the data:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 83 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   device_type                                                            60 non-null     object
#  1    software_version                                                      60 non-null     object
#  2    UID                                                                   60 non-null     int64
#  3    batch                                                                 60 non-null     int64
#  4    weekday                                                               60 non-null     object
#  5    timestamp_iso8601                                                     60 non-null     object
#  6    decimal_hour                                                          60 non-null     float64
#  7    bandwidth_FWHM_nm                                                     60 non-null     int64
#  8    field_of_view_FWHM_DEG                                                60 non-null     int64
#  9    irradiance_410nm_purple_wavelength_nm                                 60 non-null     int64
#  10   irradiance_410nm_purple_wavelength_uncertainty_nm                     60 non-null     int64
#  11   irradiance_410nm_purple_irradiance_uW_per_cm_squared                  60 non-null     float64
#  12   irradiance_410nm_purple_irradiance_uncertainty_uW_per_cm_squared      60 non-null     float64
#  13   irradiance_435nm_blue_wavelength_nm                                   60 non-null     int64
#  14   irradiance_435nm_blue_wavelength_uncertainty_nm                       60 non-null     int64
#  15   irradiance_435nm_blue_irradiance_uW_per_cm_squared                    60 non-null     float64
#  16   irradiance_435nm_blue_irradiance_uncertainty_uW_per_cm_squared        60 non-null     float64
#  17   irradiance_460nm_dodgerblue_wavelength_nm                             60 non-null     int64
#  18   irradiance_460nm_dodgerblue_wavelength_uncertainty_nm                 60 non-null     int64
#  19   irradiance_460nm_dodgerblue_irradiance_uW_per_cm_squared              60 non-null     float64
#  20   irradiance_460nm_dodgerblue_irradiance_uncertainty_uW_per_cm_squared  60 non-null     float64
#  21   irradiance_485nm_cyan_wavelength_nm                                   60 non-null     int64
#  22   irradiance_485nm_cyan_wavelength_uncertainty_nm                       60 non-null     int64
#  23   irradiance_485nm_cyan_irradiance_uW_per_cm_squared                    60 non-null     float64
#  24   irradiance_485nm_cyan_irradiance_uncertainty_uW_per_cm_squared        60 non-null     float64
#  25   irradiance_510nm_green_wavelength_nm                                  60 non-null     int64
#  26   irradiance_510nm_green_wavelength_uncertainty_nm                      60 non-null     int64
#  27   irradiance_510nm_green_irradiance_uW_per_cm_squared                   60 non-null     float64
#  28   irradiance_510nm_green_irradiance_uncertainty_uW_per_cm_squared       60 non-null     float64
#  29   irradiance_535nm_aquamarine_wavelength_nm                             60 non-null     int64
#  30   irradiance_535nm_aquamarine_wavelength_uncertainty_nm                 60 non-null     int64
#  31   irradiance_535nm_aquamarine_irradiance_uW_per_cm_squared              60 non-null     float64
#  32   irradiance_535nm_aquamarine_irradiance_uncertainty_uW_per_cm_squared  60 non-null     float64
#  33   irradiance_560nm_limegreen_wavelength_nm                              60 non-null     int64
#  34   irradiance_560nm_limegreen_wavelength_uncertainty_nm                  60 non-null     int64
#  35   irradiance_560nm_limegreen_irradiance_uW_per_cm_squared               60 non-null     float64
#  36   irradiance_560nm_limegreen_irradiance_uncertainty_uW_per_cm_squared   60 non-null     float64
#  37   irradiance_585nm_yellow_wavelength_nm                                 60 non-null     int64
#  38   irradiance_585nm_yellow_wavelength_uncertainty_nm                     60 non-null     int64
#  39   irradiance_585nm_yellow_irradiance_uW_per_cm_squared                  60 non-null     float64
#  40   irradiance_585nm_yellow_irradiance_uncertainty_uW_per_cm_squared      60 non-null     float64
#  41   irradiance_610nm_orange_wavelength_nm                                 60 non-null     int64
#  42   irradiance_610nm_orange_wavelength_uncertainty_nm                     60 non-null     int64
#  43   irradiance_610nm_orange_irradiance_uW_per_cm_squared                  60 non-null     float64
#  44   irradiance_610nm_orange_irradiance_uncertainty_uW_per_cm_squared      60 non-null     float64
#  45   irradiance_645nm_red_wavelength_nm                                    60 non-null     int64
#  46   irradiance_645nm_red_wavelength_uncertainty_nm                        60 non-null     int64
#  47   irradiance_645nm_red_irradiance_uW_per_cm_squared                     60 non-null     float64
#  48   irradiance_645nm_red_irradiance_uncertainty_uW_per_cm_squared         60 non-null     float64
#  49   irradiance_680nm_black_wavelength_nm                                  60 non-null     int64
#  50   irradiance_680nm_black_wavelength_uncertainty_nm                      60 non-null     int64
#  51   irradiance_680nm_black_irradiance_uW_per_cm_squared                   60 non-null     float64
#  52   irradiance_680nm_black_irradiance_uncertainty_uW_per_cm_squared       60 non-null     float64
#  53   irradiance_705nm_brown_wavelength_nm                                  60 non-null     int64
#  54   irradiance_705nm_brown_wavelength_uncertainty_nm                      60 non-null     int64
#  55   irradiance_705nm_brown_irradiance_uW_per_cm_squared                   60 non-null     float64
#  56   irradiance_705nm_brown_irradiance_uncertainty_uW_per_cm_squared       60 non-null     float64
#  57   irradiance_730nm_gray_wavelength_nm                                   60 non-null     int64
#  58   irradiance_730nm_gray_wavelength_uncertainty_nm                       60 non-null     int64
#  59   irradiance_730nm_gray_irradiance_uW_per_cm_squared                    60 non-null     float64
#  60   irradiance_730nm_gray_irradiance_uncertainty_uW_per_cm_squared        60 non-null     float64
#  61   irradiance_760nm_silver_wavelength_nm                                 60 non-null     int64
#  62   irradiance_760nm_silver_wavelength_uncertainty_nm                     60 non-null     int64
#  63   irradiance_760nm_silver_irradiance_uW_per_cm_squared                  60 non-null     float64
#  64   irradiance_760nm_silver_irradiance_uncertainty_uW_per_cm_squared      60 non-null     float64
#  65   irradiance_810nm_lightgray_wavelength_nm                              60 non-null     int64
#  66   irradiance_810nm_lightgray_wavelength_uncertainty_nm                  60 non-null     int64
#  67   irradiance_810nm_lightgray_irradiance_uW_per_cm_squared               60 non-null     float64
#  68   irradiance_810nm_lightgray_irradiance_uncertainty_uW_per_cm_squared   60 non-null     float64
#  69   irradiance_860nm_linen_wavelength_nm                                  60 non-null     int64
#  70   irradiance_860nm_linen_wavelength_uncertainty_nm                      60 non-null     int64
#  71   irradiance_860nm_linen_irradiance_uW_per_cm_squared                   60 non-null     float64
#  72   irradiance_860nm_linen_irradiance_uncertainty_uW_per_cm_squared       60 non-null     float64
#  73   irradiance_900nm_wheat_wavelength_nm                                  60 non-null     int64
#  74   irradiance_900nm_wheat_wavelength_uncertainty_nm                      60 non-null     int64
#  75   irradiance_900nm_wheat_irradiance_uW_per_cm_squared                   60 non-null     float64
#  76   irradiance_900nm_wheat_irradiance_uncertainty_uW_per_cm_squared       60 non-null     float64
#  77   irradiance_940nm_gold_wavelength_nm                                   60 non-null     int64
#  78   irradiance_940nm_gold_wavelength_uncertainty_nm                       60 non-null     int64
#  79   irradiance_940nm_gold_irradiance_uW_per_cm_squared                    60 non-null     float64
#  80   irradiance_940nm_gold_irradiance_uncertainty_uW_per_cm_squared        60 non-null     float64
#  81   battery_voltage                                                       60 non-null     float64
#  82   battery_percent                                                       60 non-null     int64
# dtypes: float64(38), int64(41), object(4)
# memory usage: 39.0+ KB

# %% [markdown]
# ## We did alter the original code.py file on the STELLA-Q2 to use actual color names for the following column data vs. *near IR* as in the original STELLA-Q2 code.py code file.
#
#      49   irradiance_680nm_black_wavelength_nm                                  60 non-null     int64
#      50   irradiance_680nm_black_wavelength_uncertainty_nm                      60 non-null     int64
#      51   irradiance_680nm_black_irradiance_uW_per_cm_squared                   60 non-null     float64
#      52   irradiance_680nm_black_irradiance_uncertainty_uW_per_cm_squared       60 non-null     float64
#      53   irradiance_705nm_brown_wavelength_nm                                  60 non-null     int64
#      54   irradiance_705nm_brown_wavelength_uncertainty_nm                      60 non-null     int64
#      55   irradiance_705nm_brown_irradiance_uW_per_cm_squared                   60 non-null     float64
#      56   irradiance_705nm_brown_irradiance_uncertainty_uW_per_cm_squared       60 non-null     float64
#      57   irradiance_730nm_gray_wavelength_nm                                   60 non-null     int64
#      58   irradiance_730nm_gray_wavelength_uncertainty_nm                       60 non-null     int64
#      59   irradiance_730nm_gray_irradiance_uW_per_cm_squared                    60 non-null     float64
#      60   irradiance_730nm_gray_irradiance_uncertainty_uW_per_cm_squared        60 non-null     float64
#      61   irradiance_760nm_silver_wavelength_nm                                 60 non-null     int64
#      62   irradiance_760nm_silver_wavelength_uncertainty_nm                     60 non-null     int64
#      63   irradiance_760nm_silver_irradiance_uW_per_cm_squared                  60 non-null     float64
#      64   irradiance_760nm_silver_irradiance_uncertainty_uW_per_cm_squared      60 non-null     float64
#      65   irradiance_810nm_lightgray_wavelength_nm                              60 non-null     int64
#      66   irradiance_810nm_lightgray_wavelength_uncertainty_nm                  60 non-null     int64
#      67   irradiance_810nm_lightgray_irradiance_uW_per_cm_squared               60 non-null     float64
#      68   irradiance_810nm_lightgray_irradiance_uncertainty_uW_per_cm_squared   60 non-null     float64
#      69   irradiance_860nm_linen_wavelength_nm                                  60 non-null     int64
#      70   irradiance_860nm_linen_wavelength_uncertainty_nm                      60 non-null     int64
#      71   irradiance_860nm_linen_irradiance_uW_per_cm_squared                   60 non-null     float64
#      72   irradiance_860nm_linen_irradiance_uncertainty_uW_per_cm_squared       60 non-null     float64
#      73   irradiance_900nm_wheat_wavelength_nm                                  60 non-null     int64
#      74   irradiance_900nm_wheat_wavelength_uncertainty_nm                      60 non-null     int64
#      75   irradiance_900nm_wheat_irradiance_uW_per_cm_squared                   60 non-null     float64
#      76   irradiance_900nm_wheat_irradiance_uncertainty_uW_per_cm_squared       60 non-null     float64
#      77   irradiance_940nm_gold_wavelength_nm                                   60 non-null     int64
#      78   irradiance_940nm_gold_wavelength_uncertainty_nm                       60 non-null     int64
#      79   irradiance_940nm_gold_irradiance_uW_per_cm_squared                    60 non-null     float64
#      80   irradiance_940nm_gold_irradiance_uncertainty_uW_per_cm_squared        60 non-null     float64

# %%
df.describe()
# Out:
#           UID   batch   decimal_hour   bandwidth_FWHM_nm  \
# count    60.0    60.0      60.000000                60.0
# mean   6858.0    23.0      22.328257                20.0
# std       0.0     0.0       0.007737                 0.0
# min    6858.0    23.0      22.315300                20.0
# 25%    6858.0    23.0      22.321625                20.0
# 50%    6858.0    23.0      22.328300                20.0
# 75%    6858.0    23.0      22.334850                20.0
# max    6858.0    23.0      22.341400                20.0
#
#         field_of_view_FWHM_DEG   irradiance_410nm_purple_wavelength_nm  \
# count                     60.0                                    60.0
# mean                      20.0                                   410.0
# std                        0.0                                     0.0
# min                       20.0                                   410.0
# 25%                       20.0                                   410.0
# 50%                       20.0                                   410.0
# 75%                       20.0                                   410.0
# max                       20.0                                   410.0
#
#         irradiance_410nm_purple_wavelength_uncertainty_nm  \
# count                                               60.0
# mean                                                10.0
# std                                                  0.0
# min                                                 10.0
# 25%                                                 10.0
# 50%                                                 10.0
# 75%                                                 10.0
# max                                                 10.0
#
#         irradiance_410nm_purple_irradiance_uW_per_cm_squared  \
# count                                          60.000000
# mean                                            2.354250
# std                                             3.695172
# min                                             0.000000
# 25%                                             0.851000
# 50%                                             0.851000
# 75%                                             1.702000
# max                                            17.869000
#
#         irradiance_410nm_purple_irradiance_uncertainty_uW_per_cm_squared  \
# count                                          60.000000
# mean                                            0.282367
# std                                             0.443470
# min                                             0.000000
# 25%                                             0.102000
# 50%                                             0.102000
# 75%                                             0.204000
# max                                             2.144000
#
#         irradiance_435nm_blue_wavelength_nm  ...  \
# count                                  60.0  ...
# mean                                  435.0  ...
# std                                     0.0  ...
# min                                   435.0  ...
# 25%                                   435.0  ...
# 50%                                   435.0  ...
# 75%                                   435.0  ...
# max                                   435.0  ...
#
#         irradiance_900nm_wheat_wavelength_nm  \
# count                                   60.0
# mean                                   900.0
# std                                      0.0
# min                                    900.0
# 25%                                    900.0
# 50%                                    900.0
# 75%                                    900.0
# max                                    900.0
#
#         irradiance_900nm_wheat_wavelength_uncertainty_nm  \
# count                                               60.0
# mean                                                10.0
# std                                                  0.0
# min                                                 10.0
# 25%                                                 10.0
# 50%                                                 10.0
# 75%                                                 10.0
# max                                                 10.0
#
#         irradiance_900nm_wheat_irradiance_uW_per_cm_squared  \
# count                                          60.000000
# mean                                            1.843017
# std                                             1.808570
# min                                             0.556000
# 25%                                             0.972250
# 50%                                             1.111000
# 75%                                             2.223000
# max                                             8.335000
#
#         irradiance_900nm_wheat_irradiance_uncertainty_uW_per_cm_squared  \
# count                                          60.000000
# mean                                            0.221167
# std                                             0.217032
# min                                             0.067000
# 25%                                             0.116500
# 50%                                             0.133000
# 75%                                             0.267000
# max                                             1.000000
#
#         irradiance_940nm_gold_wavelength_nm  \
# count                                  60.0
# mean                                  940.0
# std                                     0.0
# min                                   940.0
# 25%                                   940.0
# 50%                                   940.0
# 75%                                   940.0
# max                                   940.0
#
#         irradiance_940nm_gold_wavelength_uncertainty_nm  \
# count                                              60.0
# mean                                               10.0
# std                                                 0.0
# min                                                10.0
# 25%                                                10.0
# 50%                                                10.0
# 75%                                                10.0
# max                                                10.0
#
#         irradiance_940nm_gold_irradiance_uW_per_cm_squared  \
# count                                          60.000000
# mean                                            1.308600
# std                                             1.999523
# min                                             0.000000
# 25%                                             0.882000
# 50%                                             0.882000
# 75%                                             0.882000
# max                                             9.706000
#
#         irradiance_940nm_gold_irradiance_uncertainty_uW_per_cm_squared  \
# count                                          60.000000
# mean                                            0.157150
# std                                             0.239943
# min                                             0.000000
# 25%                                             0.106000
# 50%                                             0.106000
# 75%                                             0.106000
# max                                             1.165000
#
#         battery_voltage   battery_percent
# count      6.000000e+01              60.0
# mean       4.140000e+00              95.0
# std        6.269716e-15               0.0
# min        4.140000e+00              95.0
# 25%        4.140000e+00              95.0
# 50%        4.140000e+00              95.0
# 75%        4.140000e+00              95.0
# max        4.140000e+00              95.0
#
# [8 rows x 79 columns]

# %%
df.head()
# Out:
#   device_type  software_version   UID   batch  weekday  timestamp_iso8601  \
# 0   STELLA-Q2             2.4.0  6858      23   Sunday   20240204T221855Z
# 1   STELLA-Q2             2.4.0  6858      23   Sunday   20240204T221856Z
# 2   STELLA-Q2             2.4.0  6858      23   Sunday   20240204T221858Z
# 3   STELLA-Q2             2.4.0  6858      23   Sunday   20240204T221859Z
# 4   STELLA-Q2             2.4.0  6858      23   Sunday   20240204T221901Z
#
#     decimal_hour   bandwidth_FWHM_nm   field_of_view_FWHM_DEG  \
# 0        22.3153                  20                       20
# 1        22.3156                  20                       20
# 2        22.3161                  20                       20
# 3        22.3164                  20                       20
# 4        22.3169                  20                       20
#
#     irradiance_410nm_purple_wavelength_nm  ...  \
# 0                                     410  ...
# 1                                     410  ...
# 2                                     410  ...
# 3                                     410  ...
# 4                                     410  ...
#
#     irradiance_900nm_wheat_wavelength_nm  \
# 0                                    900
# 1                                    900
# 2                                    900
# 3                                    900
# 4                                    900
#
#     irradiance_900nm_wheat_wavelength_uncertainty_nm  \
# 0                                                 10
# 1                                                 10
# 2                                                 10
# 3                                                 10
# 4                                                 10
#
#     irradiance_900nm_wheat_irradiance_uW_per_cm_squared  \
# 0                                              0.556
# 1                                              0.556
# 2                                              0.556
# 3                                              1.667
# 4                                              2.223
#
#     irradiance_900nm_wheat_irradiance_uncertainty_uW_per_cm_squared  \
# 0                                              0.067
# 1                                              0.067
# 2                                              0.067
# 3                                              0.200
# 4                                              0.267
#
#     irradiance_940nm_gold_wavelength_nm  \
# 0                                   940
# 1                                   940
# 2                                   940
# 3                                   940
# 4                                   940
#
#     irradiance_940nm_gold_wavelength_uncertainty_nm  \
# 0                                                10
# 1                                                10
# 2                                                10
# 3                                                10
# 4                                                10
#
#     irradiance_940nm_gold_irradiance_uW_per_cm_squared  \
# 0                                              0.000
# 1                                              0.000
# 2                                              0.882
# 3                                              0.882
# 4                                              0.882
#
#     irradiance_940nm_gold_irradiance_uncertainty_uW_per_cm_squared  \
# 0                                              0.000
# 1                                              0.000
# 2                                              0.106
# 3                                              0.106
# 4                                              0.106
#
#     battery_voltage   battery_percent
# 0              4.14                95
# 1              4.14                95
# 2              4.14                95
# 3              4.14                95
# 4              4.14                95
#
# [5 rows x 83 columns]

# %%
# Remove leading/trailing whitespaces in column names
df.columns = df.columns.str.strip()

# %% [markdown]
# ## Plot Battery Voltage Level:

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['timestamp_iso8601'], df['battery_voltage'])
plt.ylim(3.75,4.25)
plt.xlabel('Timestamp (ISO8601)')
plt.ylabel('Battery Voltage')
plt.title('Battery Voltage Over Time')
plt.show()

# %%
# Group the data by batch number
grouped_data = df.groupby('batch')
grouped_data.head()
# Out:
#   device_type software_version   UID  batch  weekday  timestamp_iso8601  \
# 0   STELLA-Q2            2.4.0  6858     23   Sunday   20240204T221855Z
# 1   STELLA-Q2            2.4.0  6858     23   Sunday   20240204T221856Z
# 2   STELLA-Q2            2.4.0  6858     23   Sunday   20240204T221858Z
# 3   STELLA-Q2            2.4.0  6858     23   Sunday   20240204T221859Z
# 4   STELLA-Q2            2.4.0  6858     23   Sunday   20240204T221901Z
#
#    decimal_hour  bandwidth_FWHM_nm  field_of_view_FWHM_DEG  \
# 0       22.3153                 20                      20
# 1       22.3156                 20                      20
# 2       22.3161                 20                      20
# 3       22.3164                 20                      20
# 4       22.3169                 20                      20
#
#    irradiance_410nm_purple_wavelength_nm  ...  \
# 0                                    410  ...
# 1                                    410  ...
# 2                                    410  ...
# 3                                    410  ...
# 4                                    410  ...
#
#    irradiance_900nm_wheat_wavelength_nm  \
# 0                                   900
# 1                                   900
# 2                                   900
# 3                                   900
# 4                                   900
#
#    irradiance_900nm_wheat_wavelength_uncertainty_nm  \
# 0                                                10
# 1                                                10
# 2                                                10
# 3                                                10
# 4                                                10
#
#    irradiance_900nm_wheat_irradiance_uW_per_cm_squared  \
# 0                                              0.556
# 1                                              0.556
# 2                                              0.556
# 3                                              1.667
# 4                                              2.223
#
#    irradiance_900nm_wheat_irradiance_uncertainty_uW_per_cm_squared  \
# 0                                              0.067
# 1                                              0.067
# 2                                              0.067
# 3                                              0.200
# 4                                              0.267
#
#    irradiance_940nm_gold_wavelength_nm  \
# 0                                  940
# 1                                  940
# 2                                  940
# 3                                  940
# 4                                  940
#
#    irradiance_940nm_gold_wavelength_uncertainty_nm  \
# 0                                               10
# 1                                               10
# 2                                               10
# 3                                               10
# 4                                               10
#
#    irradiance_940nm_gold_irradiance_uW_per_cm_squared  \
# 0                                              0.000
# 1                                              0.000
# 2                                              0.882
# 3                                              0.882
# 4                                              0.882
#
#    irradiance_940nm_gold_irradiance_uncertainty_uW_per_cm_squared  \
# 0                                              0.000
# 1                                              0.000
# 2                                              0.106
# 3                                              0.106
# 4                                              0.106
#
#    battery_voltage  battery_percent
# 0             4.14               95
# 1             4.14               95
# 2             4.14               95
# 3             4.14               95
# 4             4.14               95
#
# [5 rows x 83 columns]

# %% [markdown]
# ## Time Series Plot from each Spectral Channel:

# %%
# List of wavelengths for plotting
#wavelengths_to_plot = [410, 435, 450, 485, 510, 535, 560, 585, 610, 645, 680]
wavelengths_to_plot= [410, 435, 460, 485, 510, 535, 560, 585, 610, 645, 680, 705, 730, 760, 810, 860, 900, 940]

# Create subplots
fig, axs = plt.subplots(len(wavelengths_to_plot), 1, figsize=(5, 1 * len(wavelengths_to_plot)), sharex=True)

# Loop through each wavelength and plot the data
for i, wavelength in enumerate(wavelengths_to_plot):
    # Use regex to match column names containing the wavelength
    wavelength_pattern = f'{wavelength}nm_(.*?)_irradiance_uW_per_cm_squared'
    wavelength_columns = [col for col in df.columns if re.search(wavelength_pattern, col)]
    
    # Plot the data for each matched column
    for column in wavelength_columns:
        color = re.search(wavelength_pattern, column).group(1)
        axs[i].plot(df['timestamp_iso8601'], df[column], label=f'{wavelength}nm - {color}')

    axs[i].set_ylabel('Irradiance (uW/cm^2)')
    axs[i].legend()

# Set common xlabel and title
plt.xlabel('Timestamp (ISO8601)')
plt.suptitle('Irradiance Over Time for Selected Wavelengths', y=0.89)

# Show the plot
plt.show()

# %% [markdown]
# # Color Spectrum data by wavelength with Gaussian curves to reflect the channel wavelength(nm) uncertainty:
#
# **Batch Index not being used yet**

# %%
# Extract all unique wavelengths
wavelengths = sorted(set(re.findall(r'(\d+)nm_', ' '.join(df.columns))))


def update_plot(timestamp_index, batch_index):
    plt.figure(figsize=(12, 6))

    timestamp = df['timestamp_iso8601'][timestamp_index]

    for wavelength in wavelengths:
        wavelength_pattern = f'{wavelength}nm_(.*?)_irradiance_uW_per_cm_squared'
        wavelength_columns = [col for col in df.columns if re.search(wavelength_pattern, col)]

        for column in wavelength_columns:
            color = 'black'  # Default color for wavelengths not explicitly defined

            # Define specific colors for certain wavelengths
            if wavelength == '410':
                color = 'purple'
            elif wavelength == '435':
                color = 'blue'
            elif wavelength == '460':
                color = 'dodgerblue'
            elif wavelength == '485':
                color = 'cyan'
            elif wavelength == '510':
                color = 'green'
            elif wavelength == '535':
                color = 'aqumarine'
            elif wavelength == '560':
                color = 'limegreen'
            elif wavelength == '585':
                color = 'yellow'
            elif wavelength == '610':
                color = 'orange'
            elif wavelength == '645':
                color = 'red'
            elif wavelength == '680':
                color = 'black'
            elif wavelength == '705':
                color = 'brown'
            elif wavelength == '730':
                color = 'gray'
            elif wavelength == '760':
                color = 'silver'
            elif wavelength == '810':
                color = 'lightgray'
            elif wavelength == '860':
                color = 'linen'
            elif wavelength == '900':
                color = 'wheat'
            elif wavelength == '940':
                color = 'gold'

            # Map custom colors to standard recognized color names
            # color = map_color(color)

            # Check if the column exists before using it
            if f'irradiance_{wavelength}nm_{color}_wavelength_nm' in df.columns and f'irradiance_{wavelength}nm_{color}_irradiance_uW_per_cm_squared' in df.columns:
                wavelength_data = df[f'irradiance_{wavelength}nm_{color}_wavelength_nm'][timestamp_index]
                irradiance_data = df[f'irradiance_{wavelength}nm_{color}_irradiance_uW_per_cm_squared'][timestamp_index]
                wavelength_uncertainty = df[f'irradiance_{wavelength}nm_{color}_wavelength_uncertainty_nm'][timestamp_index]
                irradiance_uncertainty = df[f'irradiance_{wavelength}nm_{color}_irradiance_uncertainty_uW_per_cm_squared'][timestamp_index]

                # Create a Gaussian distribution
                x_values = np.linspace(wavelength_data - 3 * wavelength_uncertainty,
                                       wavelength_data + 3 * wavelength_uncertainty, 100)
                y_values = irradiance_data * np.exp(-0.5 * ((x_values - wavelength_data) / wavelength_uncertainty) ** 2)

                # Plot Gaussian distribution
                plt.plot(x_values, y_values, label=f'{wavelength}nm - {color}', linestyle='--', linewidth=2, color=color)

                # Plot data point with error bars
                plt.errorbar(wavelength_data, irradiance_data, xerr=wavelength_uncertainty, yerr=irradiance_uncertainty,
                             linestyle='', marker='o', markersize=5, capsize=5, color=color)

                  
   # Add background colors with low alpha
    plt.axvspan(350, 400, alpha=0.5, color='plum',label='Near UV from 300-400nm')
    plt.axvspan(400, 430, alpha=0.5, color='violet',label='Violet from 400-430nm ')
    plt.axvspan(430, 490, alpha=0.2, color='blue',label='Blue from 430-490nm')
    plt.axvspan(490, 530, alpha=0.2, color='green',label='Green from 490-530nm')
    plt.axvspan(530, 580, alpha=0.2, color='yellow',label='Yellow from 530-580nm')
    plt.axvspan(580, 630, alpha=0.2, color='orange',label='Orange from 580-630nm')
    plt.axvspan(630, 700, alpha=0.2, color='red',label='Red from 630-700nm')
    plt.axvspan(700, 1000, alpha=1, color='lavender',label='Near IR from 700-1,000nm')


    plt.xlabel('Wavelength (nm)')
    plt.ylabel('Irradiance (uW/cm^2)')
    plt.xlim(350,1000)
    #plt.ylim(0,30)    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.grid()
    plt.title(f'Irradiance Over Wavelength by Timestamp {timestamp} and Batch {batch_index}')


timestamp_slider = widgets.IntSlider(value=0, min=0, max=len(df) - 1, step=1, description='Timestamp Index')
batch_slider = widgets.IntSlider(value=0, min=0, max=20, step=1, description='Batch Index')

# Create an interactive plot using widgets.interactive
interactive_plot = widgets.interactive(update_plot, timestamp_index=timestamp_slider, batch_index=batch_slider)

# Display the interactive plot
display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=0, description='Timestamp Index', max=59), IntSlider(value=0, descriptio…

# %% [markdown]
# ---
# ---
# # Test 1: Spectral Color Testing
#
# ---
# ## View data by Sample Colors. The y-axis is fixed from 0 to 14,000 for these outside photos.
#
# ![image.png](attachment:46510b79-8785-4010-b559-f1dc8ff4fb02.png)
#
# Test	 Batch
# - White	0
# - Gray	1
# - Red	2
# - Yellow	3
# - Green	4
# - Blue	5
# - Purple	6
# - Plant	7
# - Grass	8
# - Grass	9

# %%
#read the file
#file = r'data_test2.xlsx'
#file = r'data_true_colors.xlsx'
file = r'data_true_colors2.xlsx'
#file = r'data_front_yard_grass_brick.xlsx'
#file = r'data_grass_backyard_3PM_shore_at_end.xlsx'
df2 = pd.read_excel(file,index_col=False)
df2.head()
# Out:
#   device_type  software_version   UID    Test   batch     weekday  \
# 0   STELLA-Q2             2.4.0  6858   White       0   Wednesday
# 1   STELLA-Q2             2.4.0  6858    Gray       1   Wednesday
# 2   STELLA-Q2             2.4.0  6858     Red       2   Wednesday
# 3   STELLA-Q2             2.4.0  6858  Yellow       3   Wednesday
# 4   STELLA-Q2             2.4.0  6858   Green       4   Wednesday
#
#    timestamp_iso8601   decimal_hour   bandwidth_FWHM_nm  \
# 0   20240207T173644Z        17.6122                  20
# 1   20240207T173655Z        17.6153                  20
# 2   20240207T173704Z        17.6178                  20
# 3   20240207T173712Z        17.6200                  20
# 4   20240207T173722Z        17.6228                  20
#
#     field_of_view_FWHM_DEG  ...   irradiance_900nm_wheat_wavelength_nm  \
# 0                       20  ...                                    900
# 1                       20  ...                                    900
# 2                       20  ...                                    900
# 3                       20  ...                                    900
# 4                       20  ...                                    900
#
#     irradiance_900nm_wheat_wavelength_uncertainty_nm  \
# 0                                                 10
# 1                                                 10
# 2                                                 10
# 3                                                 10
# 4                                                 10
#
#     irradiance_900nm_wheat_irradiance_uW_per_cm_squared  \
# 0                                           2486.120
# 1                                            831.854
# 2                                           2088.250
# 3                                           2721.730
# 4                                           2379.430
#
#     irradiance_900nm_wheat_irradiance_uncertainty_uW_per_cm_squared  \
# 0                                            298.334
# 1                                             99.823
# 2                                            250.590
# 3                                            326.607
# 4                                            285.531
#
#     irradiance_940nm_gold_wavelength_nm  \
# 0                                   940
# 1                                   940
# 2                                   940
# 3                                   940
# 4                                   940
#
#     irradiance_940nm_gold_wavelength_uncertainty_nm  \
# 0                                                10
# 1                                                10
# 2                                                10
# 3                                                10
# 4                                                10
#
#     irradiance_940nm_gold_irradiance_uW_per_cm_squared  \
# 0                                           1966.760
# 1                                            693.528
# 2                                           1624.410
# 3                                           2105.290
# 4                                           1747.050
#
#     irradiance_940nm_gold_irradiance_uncertainty_uW_per_cm_squared  \
# 0                                            236.011
# 1                                             83.223
# 2                                            194.929
# 3                                            252.635
# 4                                            209.647
#
#     battery_voltage   battery_percent
# 0              4.17                98
# 1              4.16                98
# 2              4.16                98
# 3              4.17                98
# 4              4.17                98
#
# [5 rows x 84 columns]

# %%
# Remove leading/trailing whitespaces in column names
df2.columns = df2.columns.str.strip()

# %%
# List of wavelengths for plotting
#wavelengths_to_plot = [410, 435, 450, 485, 510, 535, 560, 585, 610, 645, 680]
wavelengths_to_plot= [410, 435, 460, 485, 510, 535, 560, 585, 610, 645, 680, 705, 730, 760, 810, 860, 900, 940]

# Create subplots
fig, axs = plt.subplots(len(wavelengths_to_plot), 1, figsize=(5, 1 * len(wavelengths_to_plot)), sharex=True)

# Loop through each wavelength and plot the data
for i, wavelength in enumerate(wavelengths_to_plot):
    # Use regex to match column names containing the wavelength
    wavelength_pattern = f'{wavelength}nm_(.*?)_irradiance_uW_per_cm_squared'
    wavelength_columns = [col for col in df2.columns if re.search(wavelength_pattern, col)]
    
    # Plot the data for each matched column
    for column in wavelength_columns:
        color = re.search(wavelength_pattern, column).group(1)
        axs[i].plot(df2['timestamp_iso8601'], df2[column], label=f'{wavelength}nm - {color}')

    axs[i].set_ylabel('Irradiance (uW/cm^2)')
    axs[i].legend()

# Set common xlabel and title
plt.xlabel('Timestamp (ISO8601)')
plt.suptitle('Irradiance Over Time for Selected Wavelengths from Outside Test Colors', y=0.89)

# Show the plot
plt.show()

# %%
# Extract all unique wavelengths
wavelengths = sorted(set(re.findall(r'(\d+)nm_', ' '.join(df2.columns))))

Test = df2['Test']

#def update_plot(timestamp_index, batch_index):
def update_plot(timestamp_index):
    
    #print(timestamp_index)
    
    plt.figure(figsize=(12, 6))

    #timestamp = df['timestamp_iso8601'][timestamp_index]
    timestamp = timestamp_index
    #test = df['Test'][Test]

    for wavelength in wavelengths:
        wavelength_pattern = f'{wavelength}nm_(.*?)_irradiance_uW_per_cm_squared'
        wavelength_columns = [col for col in df2.columns if re.search(wavelength_pattern, col)]

        for column in wavelength_columns:
            color = 'black'  # Default color for wavelengths not explicitly defined

            # Define specific colors for certain wavelengths
            if wavelength == '410':
                color = 'purple'
            elif wavelength == '435':
                color = 'blue'
            elif wavelength == '460':
                color = 'dodgerblue'
            elif wavelength == '485':
                color = 'cyan'
            elif wavelength == '510':
                color = 'green'
            elif wavelength == '535':
                color = 'aqumarine'
            elif wavelength == '560':
                color = 'limegreen'
            elif wavelength == '585':
                color = 'yellow'
            elif wavelength == '610':
                color = 'orange'
            elif wavelength == '645':
                color = 'red'
            elif wavelength == '680':
                color = 'black'
            elif wavelength == '705':
                color = 'brown'
            elif wavelength == '730':
                color = 'gray'
            elif wavelength == '760':
                color = 'silver'
            elif wavelength == '810':
                color = 'lightgray'
            elif wavelength == '860':
                color = 'linen'
            elif wavelength == '900':
                color = 'wheat'
            elif wavelength == '940':
                color = 'gold'

            # Map custom colors to standard recognized color names
            # color = map_color(color)

            # Check if the column exists before using it
            if f'irradiance_{wavelength}nm_{color}_wavelength_nm' in df2.columns and f'irradiance_{wavelength}nm_{color}_irradiance_uW_per_cm_squared' in df2.columns:
                wavelength_data = df2[f'irradiance_{wavelength}nm_{color}_wavelength_nm'][timestamp_index]
                irradiance_data = df2[f'irradiance_{wavelength}nm_{color}_irradiance_uW_per_cm_squared'][timestamp_index]
                wavelength_uncertainty = df2[f'irradiance_{wavelength}nm_{color}_wavelength_uncertainty_nm'][timestamp_index]
                irradiance_uncertainty = df2[f'irradiance_{wavelength}nm_{color}_irradiance_uncertainty_uW_per_cm_squared'][timestamp_index]

                # Create a Gaussian distribution
                x_values = np.linspace(wavelength_data - 3 * wavelength_uncertainty,
                                       wavelength_data + 3 * wavelength_uncertainty, 100)
                y_values = irradiance_data * np.exp(-0.5 * ((x_values - wavelength_data) / wavelength_uncertainty) ** 2)

                # Plot Gaussian distribution
                plt.plot(x_values, y_values, label=f'{wavelength}nm - {color}', linestyle='--', linewidth=2, color=color)

                # Plot data point with error bars
                plt.errorbar(wavelength_data, irradiance_data, xerr=wavelength_uncertainty, yerr=irradiance_uncertainty,
                             linestyle='', marker='o', markersize=5, capsize=5, color=color)
  
                  
   # Add background colors with low alpha
    plt.axvspan(350, 400, alpha=0.5, color='plum',label='Near UV from 300-400nm')
    plt.axvspan(400, 430, alpha=0.5, color='violet',label='Violet from 400-430nm ')
    plt.axvspan(430, 490, alpha=0.2, color='blue',label='Blue from 430-490nm')
    plt.axvspan(490, 530, alpha=0.2, color='green',label='Green from 490-530nm')
    plt.axvspan(530, 580, alpha=0.2, color='yellow',label='Yellow from 530-580nm')
    plt.axvspan(580, 630, alpha=0.2, color='orange',label='Orange from 580-630nm')
    plt.axvspan(630, 700, alpha=0.2, color='red',label='Red from 630-700nm')
    plt.axvspan(700, 1000, alpha=1, color='lavender',label='Near IR from 700-1,000nm')


    plt.xlabel('Wavelength (nm)')
    plt.ylabel('Irradiance (uW/cm^2)')
    plt.xlim(350,1000)
    plt.ylim(0,14000)    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.grid()
    #plt.title(f"Irradiance Over Wavelength by Timestamp {timestamp} and Batch {batch_index}: \n Test Pattern {df2['Test']}")
    plt.title(f"Irradiance Over Wavelength by Test Pattern {timestamp}: \n \n Test Pattern {df2['Test']}")

    
    
#timestamp_slider = widgets.IntSlider(value=0, min=0, max=len(df2) - 1, step=1, description='Timestamp Index')
timestamp_slider = widgets.IntSlider(value=0 , min=0, max=len(df2)-1 , step=1, description='Pattern#', continuous_update=True, orientation='horizontal')#,
    #readout=True)#,
    #readout_format='d')

#batch_slider = widgets.IntSlider(value=0, min=0, max=20, step=1, description='Batch Index')

# Create an interactive plot using widgets.interactive
interactive_plot = widgets.interactive(update_plot, timestamp_index=timestamp_slider, batch_index=batch_slider)

# Display the interactive plot
display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=0, description='Pattern#', max=9), Output()), _dom_classes=('widget-inte…

# %% [raw]
# def update_plot(timestamp_index):
#     plt.figure(figsize=(12, 6))
#
#     timestamp = timestamp_index
#
#     wavelength_data_list = []
#     irradiance_data_list = []
#
#     for wavelength in wavelengths:
#         #print(wavelength)
#         wavelength_pattern = f'{wavelength}nm_(.*?)_irradiance_uW_per_cm_squared'
#         wavelength_columns = [col for col in df2.columns if re.search(wavelength_pattern, col)]
#
#         for column in wavelength_columns:
#             color = 'black'  # Default color for wavelengths not explicitly defined
#
#             # Define specific colors for certain wavelengths (color mapping omitted for brevity)
#
#             # Check if the column exists before using it
#             if column in df2.columns:
#                 # Extract wavelength data
#                 wavelength_data = df2[column][timestamp_index]
#
#                 # Print extracted data for debugging
#                 #print(f"Wavelength: {wavelength}, Data: {wavelength_data}")
#
#                 # Append data to lists
#                 wavelength_data_list.append(wavelength)
#                 irradiance_data_list.append(wavelength_data)
#
#
#
#     print(wavelength_data_list,irradiance_data_list)
#
#
#     # Plot data point
#     plt.plot(wavelength_data_list, irradiance_data_list, linestyle='-', color='red')
#
#
#
#     plt.ylim(0,14000)
#
#
#     plt.xlabel('Wavelength (nm)')
#     plt.ylabel('Irradiance (uW/cm^2)')
#     #plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
#     plt.grid()
#     #plt.title(f"Irradiance Over Wavelength by Test Pattern {timestamp}")
#     plt.title(f"Irradiance Over Wavelength by Test Pattern {timestamp}: \n \n Test Pattern {df2['Test']}")
#
# # Create a slider widget
# timestamp_slider = widgets.IntSlider(value=0, min=0, max=len(df2) - 1, step=1, description='Timestamp Index')
#
# # Create an interactive plot using widgets.interactive
# interactive_plot = widgets.interactive(update_plot, timestamp_index=timestamp_slider)
#
# # Display the interactive plot
# display(interactive_plot)

# %%
def update_plot(timestamp_index):
    plt.figure(figsize=(12, 6))

    timestamp = timestamp_index

    wavelength_data_list = []
    irradiance_data_list = []
    
    for wavelength in wavelengths:
        wavelength_pattern = f'{wavelength}nm_(.*?)_irradiance_uW_per_cm_squared'
        wavelength_columns = [col for col in df2.columns if re.search(wavelength_pattern, col)]

        for column in wavelength_columns:
            color = 'black'  # Default color for wavelengths not explicitly defined

            # Check if the column exists before using it
            if column in df2.columns:
                # Extract wavelength data
                wavelength_data_str = wavelength
                try:
                    wavelength_data = int(wavelength_data_str)  # Convert string to integer
                except ValueError:
                    try:
                        wavelength_data = float(wavelength_data_str)  # Convert string to float
                    except ValueError:
                        continue  # Skip if wavelength cannot be converted to int or float

                # Append data to lists
                wavelength_data_list.append(wavelength_data)
                irradiance_data_list.append(df2[column][timestamp_index])
                
    # Plot data points
    plt.plot(wavelength_data_list, irradiance_data_list, linestyle='-', marker = 'o',markersize = 10, markeredgecolor = 'black', mfc = 'k', linewidth = 4,color='red')

   # Add background colors with low alpha
    plt.axvspan(350, 400, alpha=0.5, color='plum',label='Near UV from 300-400nm')
    plt.axvspan(400, 430, alpha=0.5, color='violet',label='Violet from 400-430nm ')
    plt.axvspan(430, 490, alpha=0.2, color='blue',label='Blue from 430-490nm')
    plt.axvspan(490, 530, alpha=0.2, color='green',label='Green from 490-530nm')
    plt.axvspan(530, 580, alpha=0.2, color='yellow',label='Yellow from 530-580nm')
    plt.axvspan(580, 630, alpha=0.2, color='orange',label='Orange from 580-630nm')
    plt.axvspan(630, 700, alpha=0.2, color='red',label='Red from 630-700nm')
    plt.axvspan(700, 1000, alpha=1, color='lavender',label='Near IR from 700-1,000nm')
            
    plt.xlabel('Wavelength (nm)')
    plt.ylabel('Irradiance (uW/cm^2)')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.xlim(350,1000)
    plt.ylim(0,14000)    
    plt.grid()
    plt.title(f"Irradiance Over Wavelength by Test Pattern {timestamp}: \n \n Test Pattern {df2['Test']}")

# Create a slider widget
timestamp_slider = widgets.IntSlider(value=0, min=0, max=len(df2) - 1, step=1, description='Timestamp Index')

# Create an interactive plot using widgets.interactive
interactive_plot = widgets.interactive(update_plot, timestamp_index=timestamp_slider)

# Display the interactive plot
display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=0, description='Timestamp Index', max=9), Output()), _dom_classes=('widg…

# %% [markdown]
# ## Right or wrong?
#
# If we have 18 channels with +/- 10nm uncertainty and we represent each channel with a Gaussian curve, then do we:
#
# 1. **Peak of Gaussian Curve**: Use the peak reading from each channel as the height of the Gaussian curve at its peak. This peak reading represents the maximum irradiance value detected by the sensor at that particular wavelength.This is our inital approach.
#
# 2. **Integral Under the Gaussian Curve**: Integrate each Gaussian curve over its range to calculate the total contribution of each channel to the overall irradiance. Since the uncertainty is +/- 10nm, we might integrate the Gaussian curve over this range to capture the total irradiance within the uncertainty band. An approxilation to this approach is shown below.
#
# We could use the peak reading of each channel as the height of the Gaussian curve, and then integrate under the curve to determine the total contribution of each channel to the overall irradiance. This approach allows us to capture both the peak value and the spread of the irradiance distribution due to the uncertainty. Right or Wrong?
#
# We can approximate the total integrated value under a Gaussian curve using the peak value and the standard deviation (sigma). The total integrated value under a Gaussian curve is proportional to the area under the curve, which can be calculated using the following formula:
#
#     Total integrated value ≈ peak value × standard deviation × sqrt(2π)
#
# This formula provides an approximation of the total integrated value under the Gaussian curve. Keep in mind that this formula assumes that the Gaussian curve is normalized (i.e., its area under the curve equals 1). If our Gaussian curve is not normalized, then we may need to adjust the result accordingly.
#
# Here's how we could implement this calculation in Python:
#
# ```python
# import numpy as np
#
# def total_integrated_value(peak_value, std):
#     return peak_value * std * np.sqrt(2 * np.pi)
#
# # Example usage
# peak_value = xxx  # Example peak value
# std = 10          # Example standard deviation
# total_value = total_integrated_value(peak_value, std)
# print("Total integrated value:", total_value)
# ```
#
# We can replace the `peak_value` and `std` variables with the respective values from our Gaussian curves. This function will provide an approximation of the total integrated value under the Gaussian curve.
#
# ## This next plot does not seem to be the correct approach, but is offered as an example to discuss further.

# %%
def update_plot(timestamp_index):
    plt.figure(figsize=(12, 6))

    timestamp = timestamp_index
    std = 10

    wavelength_data_list = []
    irradiance_data_list = []
    
    for wavelength in wavelengths:
        wavelength_pattern = f'{wavelength}nm_(.*?)_irradiance_uW_per_cm_squared'
        wavelength_columns = [col for col in df2.columns if re.search(wavelength_pattern, col)]

        for column in wavelength_columns:
            color = 'black'  # Default color for wavelengths not explicitly defined

            # Check if the column exists before using it
            if column in df2.columns:
                # Extract wavelength data
                wavelength_data_str = wavelength
                try:
                    wavelength_data = int(wavelength_data_str)  # Convert string to integer
                except ValueError:
                    try:
                        wavelength_data = float(wavelength_data_str)  # Convert string to float
                    except ValueError:
                        continue  # Skip if wavelength cannot be converted to int or float

                # Append data to lists
                wavelength_data_list.append(wavelength_data)
                irradiance_data_list.append(df2[column][timestamp_index]*std * np.sqrt(2 * np.pi))
                
    #print(irradiance_data_list)
    # Plot data points
    plt.plot(wavelength_data_list, irradiance_data_list, linestyle='-', linewidth = 4,color='red', marker = 'o',markersize = 10, markeredgecolor = 'black', mfc = 'k')

   # Add background colors with low alpha
    plt.axvspan(350, 400, alpha=0.5, color='plum',label='Near UV from 300-400nm')
    plt.axvspan(400, 430, alpha=0.5, color='violet',label='Violet from 400-430nm ')
    plt.axvspan(430, 490, alpha=0.2, color='blue',label='Blue from 430-490nm')
    plt.axvspan(490, 530, alpha=0.2, color='green',label='Green from 490-530nm')
    plt.axvspan(530, 580, alpha=0.2, color='yellow',label='Yellow from 530-580nm')
    plt.axvspan(580, 630, alpha=0.2, color='orange',label='Orange from 580-630nm')
    plt.axvspan(630, 700, alpha=0.2, color='red',label='Red from 630-700nm')
    plt.axvspan(700, 1000, alpha=1, color='lavender',label='Near IR from 700-1,000nm')
            
    plt.xlabel('Wavelength (nm)')
    plt.ylabel('Irradiance (uW/cm^2)')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.xlim(350,1000)
    plt.ylim(0,350000)    
    plt.grid()
    plt.title(f"Irradiance Over Wavelength by Test Pattern {timestamp}: \n \n Test Pattern {df2['Test']}")

# Create a slider widget
timestamp_slider = widgets.IntSlider(value=0, min=0, max=len(df2) - 1, step=1, description='Timestamp Index')

# Create an interactive plot using widgets.interactive
interactive_plot = widgets.interactive(update_plot, timestamp_index=timestamp_slider)

# Display the interactive plot
display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=0, description='Timestamp Index', max=9), Output()), _dom_classes=('widg…

# %% [raw]
# def gaussian_distribution(x, mean, std):
#     return np.exp(-((x - mean) ** 2) / (2 * std ** 2))
#
# def convolve_with_gaussian(wavelengths, irradiance_values, std):
#     new_irradiance_values = []
#     for i, wavelength in enumerate(wavelengths):
#         gaussian = gaussian_distribution(wavelengths, wavelength, std)
#         weighted_irradiance = irradiance_values * gaussian
#         new_irradiance_values.append(np.sum(weighted_irradiance))
#     return new_irradiance_values
#
# # Example usage
# wavelengths = np.linspace(300, 800, 18)  # Example wavelengths
# irradiance_values = np.random.rand(18) * 100  # Example original irradiance values
# std = 10  # Standard deviation of the Gaussian distribution
#
# new_irradiance_values = convolve_with_gaussian(wavelengths, irradiance_values, std)

# %% [markdown]
# ## All Readings for Test 1: Spectral Color Testing
#
# Timestamp not implemented on this plot.

# %%
# Extract all unique wavelengths
wavelengths = sorted(set(re.findall(r'(\d+)nm_', ' '.join(df2.columns))))

# Function to update the plot based on selected timestamp
def update_plot(timestamp_index):
    plt.figure(figsize=(12, 6))

    timestamp = df2['timestamp_iso8601'][timestamp_index]

    for wavelength in wavelengths:
        wavelength_pattern = f'{wavelength}nm_(.*?)_irradiance_uW_per_cm_squared'
        wavelength_columns = [col for col in df2.columns if re.search(wavelength_pattern, col)]

        for column in wavelength_columns:
            color = re.search(wavelength_pattern, column).group(1)

            wavelength_data = df2[f'irradiance_{wavelength}nm_{color}_wavelength_nm']
            irradiance_data = df2[column]
            wavelength_uncertainty = df2[f'irradiance_{wavelength}nm_{color}_wavelength_uncertainty_nm']
            irradiance_uncertainty = df2[f'irradiance_{wavelength}nm_{color}_irradiance_uncertainty_uW_per_cm_squared']

            plt.errorbar(wavelength_data, irradiance_data, xerr=wavelength_uncertainty, yerr=irradiance_uncertainty,color=color,
                         label=f'{wavelength}nm - {color}', linestyle='', marker='o', markersize=3, capsize=3)

   # Add background colors with low alpha
    plt.axvspan(350, 400, alpha=0.5, color='plum',label='Near UV from 300-400nm')
    plt.axvspan(400, 430, alpha=0.5, color='violet',label='Violet from 400-430nm ')
    plt.axvspan(430, 490, alpha=0.2, color='blue',label='Blue from 430-490nm')
    plt.axvspan(490, 530, alpha=0.2, color='green',label='Green from 490-530nm')
    plt.axvspan(530, 580, alpha=0.2, color='yellow',label='Yellow from 530-580nm')
    plt.axvspan(580, 630, alpha=0.2, color='orange',label='Orange from 580-630nm')
    plt.axvspan(630, 700, alpha=0.2, color='red',label='Red from 630-700nm')
    plt.axvspan(700, 1000, alpha=1, color='lavender',label='Near IR from 700-1,000nm')
           
            
            
    plt.xlabel('Wavelength (nm)')
    plt.ylabel('Irradiance (uW/cm^2)')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.xlim(350,1000)
    plt.ylim(0,14000)    
 
    plt.grid()
    #plt.title(f'Irradiance Over Wavelength - {timestamp}')
    plt.title(f"Irradiance Over Wavelength for all Test Patterns {timestamp_index}: \n \n Test Pattern {df2['Test']}")


# Create a slider widget
timestamp_slider = widgets.IntSlider(value=0, min=0, max=len(df2) - 1, step=1, description='Timestamp Index',disabled=True,)

# Create an interactive plot using widgets.interactive
interactive_plot = widgets.interactive(update_plot, timestamp_index=timestamp_slider)

# Display the interactive plot
display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=0, description='Timestamp Index', disabled=True, max=9), Output()), _dom…

# %% [markdown]
# ---
# ---
#
# # Test 2: Backyard Grass and Shoreline (at end of data) in continous mode of recording.
#
# Readings taken in February where much of the grass was brown indicative of winter dormancy.
#
# ![image.png](attachment:7ce731e3-a72c-4d42-83d7-07bbbec4ab3f.png)

# %%
#read the file
#file = r'data_test2.xlsx'
#file = r'data_true_colors.xlsx'
#file = r'data_true_colors2.xlsx'
#file = r'data_front_yard_grass_brick.xlsx'
file = r'data_grass_backyard_3PM_shore_at_end.xlsx'
df3 = pd.read_excel(file,index_col=False)
df3.head()
# Out:
#   device_type  software_version   UID   Test   batch     weekday  \
# 0   STELLA-Q2             2.4.0  6858  Grass      23   Wednesday
# 1   STELLA-Q2             2.4.0  6858  Grass      23   Wednesday
# 2   STELLA-Q2             2.4.0  6858  Grass      23   Wednesday
# 3   STELLA-Q2             2.4.0  6858  Grass      23   Wednesday
# 4   STELLA-Q2             2.4.0  6858  Grass      23   Wednesday
#
#    timestamp_iso8601   decimal_hour   bandwidth_FWHM_nm  \
# 0   20240207T202445Z        20.4125                  20
# 1   20240207T202446Z        20.4128                  20
# 2   20240207T202448Z        20.4133                  20
# 3   20240207T202449Z        20.4136                  20
# 4   20240207T202451Z        20.4142                  20
#
#     field_of_view_FWHM_DEG  ...   irradiance_900nm_wheat_wavelength_nm  \
# 0                       20  ...                                    900
# 1                       20  ...                                    900
# 2                       20  ...                                    900
# 3                       20  ...                                    900
# 4                       20  ...                                    900
#
#     irradiance_900nm_wheat_wavelength_uncertainty_nm  \
# 0                                                 10
# 1                                                 10
# 2                                                 10
# 3                                                 10
# 4                                                 10
#
#     irradiance_900nm_wheat_irradiance_uW_per_cm_squared  \
# 0                                            1944.88
# 1                                            1949.33
# 2                                            1949.33
# 3                                            1951.00
# 4                                            1823.19
#
#     irradiance_900nm_wheat_irradiance_uncertainty_uW_per_cm_squared  \
# 0                                            233.386
# 1                                            233.919
# 2                                            233.919
# 3                                            234.120
# 4                                            218.783
#
#     irradiance_940nm_gold_wavelength_nm  \
# 0                                   940
# 1                                   940
# 2                                   940
# 3                                   940
# 4                                   940
#
#     irradiance_940nm_gold_wavelength_uncertainty_nm  \
# 0                                                10
# 1                                                10
# 2                                                10
# 3                                                10
# 4                                                10
#
#     irradiance_940nm_gold_irradiance_uW_per_cm_squared  \
# 0                                            1430.29
# 1                                            1430.29
# 2                                            1432.06
# 3                                            1430.29
# 4                                            1324.41
#
#     irradiance_940nm_gold_irradiance_uncertainty_uW_per_cm_squared  \
# 0                                            171.635
# 1                                            171.635
# 2                                            171.847
# 3                                            171.635
# 4                                            158.929
#
#     battery_voltage   battery_percent
# 0              4.17                98
# 1              4.17                98
# 2              4.17                98
# 3              4.16                98
# 4              4.17                98
#
# [5 rows x 84 columns]

# %%
# Remove leading/trailing whitespaces in column names
df3.columns = df3.columns.str.strip()

# %%
# List of wavelengths for plotting
#wavelengths_to_plot = [410, 435, 450, 485, 510, 535, 560, 585, 610, 645, 680]
wavelengths_to_plot= [410, 435, 460, 485, 510, 535, 560, 585, 610, 645, 680, 705, 730, 760, 810, 860, 900, 940]

# Create subplots
fig, axs = plt.subplots(len(wavelengths_to_plot), 1, figsize=(5, 1 * len(wavelengths_to_plot)), sharex=True)

# Loop through each wavelength and plot the data
for i, wavelength in enumerate(wavelengths_to_plot):
    # Use regex to match column names containing the wavelength
    wavelength_pattern = f'{wavelength}nm_(.*?)_irradiance_uW_per_cm_squared'
    wavelength_columns = [col for col in df3.columns if re.search(wavelength_pattern, col)]
    
    # Plot the data for each matched column
    for column in wavelength_columns:
        color = re.search(wavelength_pattern, column).group(1)
        axs[i].plot(df3['timestamp_iso8601'], df3[column], label=f'{wavelength}nm - {color}')

    axs[i].set_ylabel('Irradiance (uW/cm^2)')
    axs[i].legend()

# Set common xlabel and title
plt.xlabel('Timestamp (ISO8601)')
plt.suptitle('Irradiance Over Time for Selected Wavelengths taken in Backyard', y=0.89)

# Show the plot
plt.show()

# %% [markdown]
# ## The shoreline at the end has lower Irradiance than the grass, especially in the near IR regions.

# %% [raw]
# # List of wavelengths for plotting
# wavelengths_to_plot = [410, 435, 460, 485, 510, 535, 560, 585, 610, 645, 680, 705, 730, 760, 810, 860, 900, 940]
#
# # Create subplots
# fig, axs = plt.subplots(len(wavelengths_to_plot), 1, figsize=(5, 1 * len(wavelengths_to_plot)), sharex=True)
#
# # Loop through each wavelength and plot the data
# for i, wavelength in enumerate(wavelengths_to_plot):
#     # Use regex to match column names containing the wavelength
#     wavelength_pattern = f'{wavelength}nm_(.*?)_irradiance_uW_per_cm_squared'
#     wavelength_columns = [col for col in df3.columns if re.search(wavelength_pattern, col)]
#
#     # Plot the data for each matched column
#     for column in wavelength_columns:
#         color = re.search(wavelength_pattern, column).group(1)
#         axs[i].plot(df3['timestamp_iso8601'], df3[column], label=f'{wavelength}nm - {color}')
#
#         # Remove box around each plot
#         axs[i].spines['top'].set_visible(False)
#         axs[i].spines['right'].set_visible(False)
#         axs[i].spines['bottom'].set_visible(False)
#         axs[i].spines['left'].set_visible(False)
#
#         # Adjust tick parameters
#         axs[i].tick_params(axis='x', which='both', bottom=False, top=False)
#         axs[i].tick_params(axis='y', which='both', left=False, right=False)
#
#     axs[i].set_ylabel('Irradiance (uW/cm^2)')
#     axs[i].legend()
#     #axs[i].grid()
#     axs[i].set_ylim(0,10000)
#
# # Set common xlabel and title
# plt.xlabel('Timestamp (ISO8601)')
# ######plt.title('Irradiance Over Time for Selected Wavelengths taken in Backyard', y=0.89)
# # Adjust layout
# plt.tight_layout()
#
# # Show the plot
# plt.show()

# %%
# Extract all unique wavelengths
wavelengths = sorted(set(re.findall(r'(\d+)nm_', ' '.join(df3.columns))))

Test = df3['Test']

#def update_plot(timestamp_index, batch_index):
def update_plot(timestamp_index):
    
    #print(timestamp_index)
    
    plt.figure(figsize=(12, 6))

    #timestamp = df3['timestamp_iso8601'][timestamp_index]
    timestamp = timestamp_index
    #test = df3['Test'][Test]

    for wavelength in wavelengths:
        wavelength_pattern = f'{wavelength}nm_(.*?)_irradiance_uW_per_cm_squared'
        wavelength_columns = [col for col in df3.columns if re.search(wavelength_pattern, col)]

        for column in wavelength_columns:
            color = 'black'  # Default color for wavelengths not explicitly defined

            # Define specific colors for certain wavelengths
            if wavelength == '410':
                color = 'purple'
            elif wavelength == '435':
                color = 'blue'
            elif wavelength == '460':
                color = 'dodgerblue'
            elif wavelength == '485':
                color = 'cyan'
            elif wavelength == '510':
                color = 'green'
            elif wavelength == '535':
                color = 'aqumarine'
            elif wavelength == '560':
                color = 'limegreen'
            elif wavelength == '585':
                color = 'yellow'
            elif wavelength == '610':
                color = 'orange'
            elif wavelength == '645':
                color = 'red'
            elif wavelength == '680':
                color = 'black'
            elif wavelength == '705':
                color = 'brown'
            elif wavelength == '730':
                color = 'gray'
            elif wavelength == '760':
                color = 'silver'
            elif wavelength == '810':
                color = 'lightgray'
            elif wavelength == '860':
                color = 'linen'
            elif wavelength == '900':
                color = 'wheat'
            elif wavelength == '940':
                color = 'gold'

            # Map custom colors to standard recognized color names
            # color = map_color(color)

            # Check if the column exists before using it
            if f'irradiance_{wavelength}nm_{color}_wavelength_nm' in df3.columns and f'irradiance_{wavelength}nm_{color}_irradiance_uW_per_cm_squared' in df3.columns:
                wavelength_data = df3[f'irradiance_{wavelength}nm_{color}_wavelength_nm'][timestamp_index]
                irradiance_data = df3[f'irradiance_{wavelength}nm_{color}_irradiance_uW_per_cm_squared'][timestamp_index]
                wavelength_uncertainty = df3[f'irradiance_{wavelength}nm_{color}_wavelength_uncertainty_nm'][timestamp_index]
                irradiance_uncertainty = df3[f'irradiance_{wavelength}nm_{color}_irradiance_uncertainty_uW_per_cm_squared'][timestamp_index]

                # Create a Gaussian distribution
                x_values = np.linspace(wavelength_data - 3 * wavelength_uncertainty,
                                       wavelength_data + 3 * wavelength_uncertainty, 100)
                y_values = irradiance_data * np.exp(-0.5 * ((x_values - wavelength_data) / wavelength_uncertainty) ** 2)

                # Plot Gaussian distribution
                plt.plot(x_values, y_values, label=f'{wavelength}nm - {color}', linestyle='--', linewidth=2, color=color)

                # Plot data point with error bars
                plt.errorbar(wavelength_data, irradiance_data, xerr=wavelength_uncertainty, yerr=irradiance_uncertainty,
                             linestyle='', marker='o', markersize=5, capsize=5, color=color)

                  
   # Add background colors with low alpha
    plt.axvspan(350, 400, alpha=0.5, color='plum',label='Near UV from 300-400nm')
    plt.axvspan(400, 430, alpha=0.5, color='violet',label='Violet from 400-430nm ')
    plt.axvspan(430, 490, alpha=0.2, color='blue',label='Blue from 430-490nm')
    plt.axvspan(490, 530, alpha=0.2, color='green',label='Green from 490-530nm')
    plt.axvspan(530, 580, alpha=0.2, color='yellow',label='Yellow from 530-580nm')
    plt.axvspan(580, 630, alpha=0.2, color='orange',label='Orange from 580-630nm')
    plt.axvspan(630, 700, alpha=0.2, color='red',label='Red from 630-700nm')
    plt.axvspan(700, 1000, alpha=1, color='lavender',label='Near IR from 700-1,000nm')


    plt.xlabel('Wavelength (nm)')
    plt.ylabel('Irradiance (uW/cm^2)')
    plt.xlim(350,1000)
    plt.ylim(0,14000)    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.grid()
    #plt.title(f"Irradiance Over Wavelength by Timestamp {timestamp} and Batch {batch_index}: \n Test Pattern {df3['Test']}")
    plt.title(f"Irradiance Over Wavelength for Backyard Readings {timestamp}: \n \n Test Pattern {df3['Test']}")

    
    
#timestamp_slider = widgets.IntSlider(value=0, min=0, max=len(df3) - 1, step=1, description='Timestamp Index')
timestamp_slider = widgets.IntSlider(value=0 , min=0, max=len(df3)-1 , step=1, description='Pattern#', continuous_update=True, orientation='horizontal')#,
    #readout=True)#,
    #readout_format='d')

#batch_slider = widgets.IntSlider(value=0, min=0, max=20, step=1, description='Batch Index')

# Create an interactive plot using widgets.interactive
interactive_plot = widgets.interactive(update_plot, timestamp_index=timestamp_slider, batch_index=batch_slider)

# Display the interactive plot
display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=0, description='Pattern#', max=86), Output()), _dom_classes=('widget-int…

# %%
def update_plot(timestamp_index):
    plt.figure(figsize=(12, 6))

    timestamp = timestamp_index

    wavelength_data_list = []
    irradiance_data_list = []
    
    for wavelength in wavelengths:
        wavelength_pattern = f'{wavelength}nm_(.*?)_irradiance_uW_per_cm_squared'
        wavelength_columns = [col for col in df3.columns if re.search(wavelength_pattern, col)]

        for column in wavelength_columns:
            color = 'black'  # Default color for wavelengths not explicitly defined

            # Check if the column exists before using it
            if column in df3.columns:
                # Extract wavelength data
                wavelength_data_str = wavelength
                try:
                    wavelength_data = int(wavelength_data_str)  # Convert string to integer
                except ValueError:
                    try:
                        wavelength_data = float(wavelength_data_str)  # Convert string to float
                    except ValueError:
                        continue  # Skip if wavelength cannot be converted to int or float

                # Append data to lists
                wavelength_data_list.append(wavelength_data)
                irradiance_data_list.append(df3[column][timestamp_index])
                
    # Plot data points
    plt.plot(wavelength_data_list, irradiance_data_list, linestyle='-', marker = 'o',markersize = 10, markeredgecolor = 'black', mfc = 'k', linewidth = 4,color='red')

   # Add background colors with low alpha
    plt.axvspan(350, 400, alpha=0.5, color='plum',label='Near UV from 300-400nm')
    plt.axvspan(400, 430, alpha=0.5, color='violet',label='Violet from 400-430nm ')
    plt.axvspan(430, 490, alpha=0.2, color='blue',label='Blue from 430-490nm')
    plt.axvspan(490, 530, alpha=0.2, color='green',label='Green from 490-530nm')
    plt.axvspan(530, 580, alpha=0.2, color='yellow',label='Yellow from 530-580nm')
    plt.axvspan(580, 630, alpha=0.2, color='orange',label='Orange from 580-630nm')
    plt.axvspan(630, 700, alpha=0.2, color='red',label='Red from 630-700nm')
    plt.axvspan(700, 1000, alpha=1, color='lavender',label='Near IR from 700-1,000nm')
            
    plt.xlabel('Wavelength (nm)')
    plt.ylabel('Irradiance (uW/cm^2)')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.xlim(350,1000)
    plt.ylim(0,14000)    
    plt.grid()
    plt.title(f"Irradiance Over Wavelength by Test Pattern {timestamp}: \n \n Test Pattern {df3['Test']}")

# Create a slider widget
timestamp_slider = widgets.IntSlider(value=0, min=0, max=len(df3) - 1, step=1, description='Timestamp Index')

# Create an interactive plot using widgets.interactive
interactive_plot = widgets.interactive(update_plot, timestamp_index=timestamp_slider)

# Display the interactive plot
display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=0, description='Timestamp Index', max=86), Output()), _dom_classes=('wid…

# %% [markdown]
# ## All Backyard Grass and Shoreline samples:
#
# Timestamp not implemented yet.

# %%
# Extract all unique wavelengths
wavelengths = sorted(set(re.findall(r'(\d+)nm_', ' '.join(df3.columns))))

# Function to update the plot based on selected timestamp
def update_plot(timestamp_index):
    plt.figure(figsize=(12, 6))

    timestamp = df3['timestamp_iso8601'][timestamp_index]

    for wavelength in wavelengths:
        wavelength_pattern = f'{wavelength}nm_(.*?)_irradiance_uW_per_cm_squared'
        wavelength_columns = [col for col in df3.columns if re.search(wavelength_pattern, col)]

        for column in wavelength_columns:
            color = re.search(wavelength_pattern, column).group(1)

            wavelength_data = df3[f'irradiance_{wavelength}nm_{color}_wavelength_nm']
            irradiance_data = df3[column]
            wavelength_uncertainty = df3[f'irradiance_{wavelength}nm_{color}_wavelength_uncertainty_nm']
            irradiance_uncertainty = df3[f'irradiance_{wavelength}nm_{color}_irradiance_uncertainty_uW_per_cm_squared']

            plt.errorbar(wavelength_data, irradiance_data, xerr=wavelength_uncertainty, yerr=irradiance_uncertainty,color=color,
                         label=f'{wavelength}nm - {color}', linestyle='', marker='o', markersize=3, capsize=3)

   # Add background colors with low alpha
    plt.axvspan(350, 400, alpha=0.5, color='plum',label='Near UV from 300-400nm')
    plt.axvspan(400, 430, alpha=0.5, color='violet',label='Violet from 400-430nm ')
    plt.axvspan(430, 490, alpha=0.2, color='blue',label='Blue from 430-490nm')
    plt.axvspan(490, 530, alpha=0.2, color='green',label='Green from 490-530nm')
    plt.axvspan(530, 580, alpha=0.2, color='yellow',label='Yellow from 530-580nm')
    plt.axvspan(580, 630, alpha=0.2, color='orange',label='Orange from 580-630nm')
    plt.axvspan(630, 700, alpha=0.2, color='red',label='Red from 630-700nm')
    plt.axvspan(700, 1000, alpha=1, color='lavender',label='Near IR from 700-1,000nm')
           
            
            
    plt.xlabel('Wavelength (nm)')
    plt.ylabel('Irradiance (uW/cm^2)')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.xlim(350,1000)
    plt.ylim(0,14000)    
 
    plt.grid()
    #plt.title(f'Irradiance Over Wavelength - {timestamp}')
    plt.title(f"Irradiance Over Wavelength for all Backyard Readings {timestamp_index}: \n \n Test Pattern {df3['Test']}")


# Create a slider widget
timestamp_slider = widgets.IntSlider(value=0, min=0, max=len(df3) - 1, step=1, description='Timestamp Index',disabled=True,)

# Create an interactive plot using widgets.interactive
interactive_plot = widgets.interactive(update_plot, timestamp_index=timestamp_slider)

# Display the interactive plot
display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=0, description='Timestamp Index', disabled=True, max=86), Output()), _do…

# %% [markdown]
# ---
# ---
#
# # Test 3: Front and Backyard Grass Only from continous mode of recording and then 2 files merged in Excel.
#
# - Front Yard Readings taken at 1:00 PM
# - Backyared Readings taken at 3:00PM
#
# ![image.png](attachment:72702210-44b1-4072-884c-e11c424db7e9.png)

# %%
#read the file
#file = r'data_test2.xlsx'
#file = r'data_true_colors.xlsx'
#file = r'data_true_colors2.xlsx'
#file = r'data_front_yard_grass_brick.xlsx'
#file = r'data_grass_backyard_3PM_shore_at_end.xlsx'
file = r'data_grass_front_1PM_backyard_3PM.xlsx'

df4 = pd.read_excel(file,index_col=False)
df4.head()
# Out:
#   device_type  software_version   UID              Test   batch     weekday  \
# 0   STELLA-Q2             2.4.0  6858  Front Grass 1:PM      22   Wednesday
# 1   STELLA-Q2             2.4.0  6858  Front Grass 1:PM      22   Wednesday
# 2   STELLA-Q2             2.4.0  6858  Front Grass 1:PM      22   Wednesday
# 3   STELLA-Q2             2.4.0  6858  Front Grass 1:PM      22   Wednesday
# 4   STELLA-Q2             2.4.0  6858  Front Grass 1:PM      22   Wednesday
#
#    timestamp_iso8601   decimal_hour   bandwidth_FWHM_nm  \
# 0   20240207T185220Z        18.8722                  20
# 1   20240207T185221Z        18.8725                  20
# 2   20240207T185223Z        18.8730                  20
# 3   20240207T185225Z        18.8736                  20
# 4   20240207T185226Z        18.8739                  20
#
#     field_of_view_FWHM_DEG  ...   irradiance_900nm_wheat_wavelength_nm  \
# 0                       20  ...                                    900
# 1                       20  ...                                    900
# 2                       20  ...                                    900
# 3                       20  ...                                    900
# 4                       20  ...                                    900
#
#     irradiance_900nm_wheat_wavelength_uncertainty_nm  \
# 0                                                 10
# 1                                                 10
# 2                                                 10
# 3                                                 10
# 4                                                 10
#
#     irradiance_900nm_wheat_irradiance_uW_per_cm_squared  \
# 0                                            1081.35
# 1                                            2467.78
# 2                                            2400.54
# 3                                            2287.74
# 4                                            2513.90
#
#     irradiance_900nm_wheat_irradiance_uncertainty_uW_per_cm_squared  \
# 0                                            129.763
# 1                                            296.133
# 2                                            288.065
# 3                                            274.529
# 4                                            301.668
#
#     irradiance_940nm_gold_wavelength_nm  \
# 0                                   940
# 1                                   940
# 2                                   940
# 3                                   940
# 4                                   940
#
#     irradiance_940nm_gold_wavelength_uncertainty_nm  \
# 0                                                10
# 1                                                10
# 2                                                10
# 3                                                10
# 4                                                10
#
#     irradiance_940nm_gold_irradiance_uW_per_cm_squared  \
# 0                                            793.234
# 1                                           1866.170
# 2                                           1772.640
# 3                                           1533.530
# 4                                           1852.050
#
#     irradiance_940nm_gold_irradiance_uncertainty_uW_per_cm_squared  \
# 0                                             95.188
# 1                                            223.941
# 2                                            212.717
# 3                                            184.023
# 4                                            222.247
#
#     battery_voltage   battery_percent
# 0              4.17                98
# 1              4.17                98
# 2              4.17                98
# 3              4.17                98
# 4              4.17                98
#
# [5 rows x 84 columns]

# %%
# Remove leading/trailing whitespaces in column names
df4.columns = df4.columns.str.strip()

# List of wavelengths for plotting
#wavelengths_to_plot = [410, 435, 450, 485, 510, 535, 560, 585, 610, 645, 680]
wavelengths_to_plot= [410, 435, 460, 485, 510, 535, 560, 585, 610, 645, 680, 705, 730, 760, 810, 860, 900, 940]

# Create subplots
fig, axs = plt.subplots(len(wavelengths_to_plot), 1, figsize=(5, 1 * len(wavelengths_to_plot)), sharex=True)

# Loop through each wavelength and plot the data
for i, wavelength in enumerate(wavelengths_to_plot):
    # Use regex to match column names containing the wavelength
    wavelength_pattern = f'{wavelength}nm_(.*?)_irradiance_uW_per_cm_squared'
    wavelength_columns = [col for col in df4.columns if re.search(wavelength_pattern, col)]
    
    # Plot the data for each matched column
    for column in wavelength_columns:
        color = re.search(wavelength_pattern, column).group(1)
        axs[i].plot(df4['timestamp_iso8601'], df4[column], label=f'{wavelength}nm - {color}')

    axs[i].set_ylabel('Irradiance (uW/cm^2)')
    axs[i].legend()

# Set common xlabel and title
plt.xlabel('Timestamp (ISO8601)')
plt.suptitle('Irradiance Over Time for Selected Wavelengths taken in Backyard', y=0.89)

# Show the plot
plt.show()

# %% [markdown]
# ## Notice time-series data above changes in magnitude from the 1:00PM front yard grass readings with the 3:00PM back yard grass readings that appear to have had less direct sunlight.

# %%
# Extract all unique wavelengths
wavelengths = sorted(set(re.findall(r'(\d+)nm_', ' '.join(df4.columns))))

Test = df4['Test']

#def update_plot(timestamp_index, batch_index):
def update_plot(timestamp_index):
    
    #print(timestamp_index)
    
    plt.figure(figsize=(12, 6))

    #timestamp = df3['timestamp_iso8601'][timestamp_index]
    timestamp = timestamp_index
    #test = df3['Test'][Test]

    for wavelength in wavelengths:
        wavelength_pattern = f'{wavelength}nm_(.*?)_irradiance_uW_per_cm_squared'
        wavelength_columns = [col for col in df4.columns if re.search(wavelength_pattern, col)]

        for column in wavelength_columns:
            color = 'black'  # Default color for wavelengths not explicitly defined

            # Define specific colors for certain wavelengths
            if wavelength == '410':
                color = 'purple'
            elif wavelength == '435':
                color = 'blue'
            elif wavelength == '460':
                color = 'dodgerblue'
            elif wavelength == '485':
                color = 'cyan'
            elif wavelength == '510':
                color = 'green'
            elif wavelength == '535':
                color = 'aqumarine'
            elif wavelength == '560':
                color = 'limegreen'
            elif wavelength == '585':
                color = 'yellow'
            elif wavelength == '610':
                color = 'orange'
            elif wavelength == '645':
                color = 'red'
            elif wavelength == '680':
                color = 'black'
            elif wavelength == '705':
                color = 'brown'
            elif wavelength == '730':
                color = 'gray'
            elif wavelength == '760':
                color = 'silver'
            elif wavelength == '810':
                color = 'lightgray'
            elif wavelength == '860':
                color = 'linen'
            elif wavelength == '900':
                color = 'wheat'
            elif wavelength == '940':
                color = 'gold'

            # Map custom colors to standard recognized color names
            # color = map_color(color)

            # Check if the column exists before using it
            if f'irradiance_{wavelength}nm_{color}_wavelength_nm' in df4.columns and f'irradiance_{wavelength}nm_{color}_irradiance_uW_per_cm_squared' in df4.columns:
                wavelength_data = df4[f'irradiance_{wavelength}nm_{color}_wavelength_nm'][timestamp_index]
                irradiance_data = df4[f'irradiance_{wavelength}nm_{color}_irradiance_uW_per_cm_squared'][timestamp_index]
                wavelength_uncertainty = df4[f'irradiance_{wavelength}nm_{color}_wavelength_uncertainty_nm'][timestamp_index]
                irradiance_uncertainty = df4[f'irradiance_{wavelength}nm_{color}_irradiance_uncertainty_uW_per_cm_squared'][timestamp_index]

                # Create a Gaussian distribution
                x_values = np.linspace(wavelength_data - 3 * wavelength_uncertainty,
                                       wavelength_data + 3 * wavelength_uncertainty, 100)
                y_values = irradiance_data * np.exp(-0.5 * ((x_values - wavelength_data) / wavelength_uncertainty) ** 2)

                # Plot Gaussian distribution
                plt.plot(x_values, y_values, label=f'{wavelength}nm - {color}', linestyle='--', linewidth=2, color=color)

                # Plot data point with error bars
                plt.errorbar(wavelength_data, irradiance_data, xerr=wavelength_uncertainty, yerr=irradiance_uncertainty,
                             linestyle='', marker='o', markersize=5, capsize=5, color=color)

                  
   # Add background colors with low alpha
    plt.axvspan(350, 400, alpha=0.5, color='plum',label='Near UV from 300-400nm')
    plt.axvspan(400, 430, alpha=0.5, color='violet',label='Violet from 400-430nm ')
    plt.axvspan(430, 490, alpha=0.2, color='blue',label='Blue from 430-490nm')
    plt.axvspan(490, 530, alpha=0.2, color='green',label='Green from 490-530nm')
    plt.axvspan(530, 580, alpha=0.2, color='yellow',label='Yellow from 530-580nm')
    plt.axvspan(580, 630, alpha=0.2, color='orange',label='Orange from 580-630nm')
    plt.axvspan(630, 700, alpha=0.2, color='red',label='Red from 630-700nm')
    plt.axvspan(700, 1000, alpha=1, color='lavender',label='Near IR from 700-1,000nm')


    plt.xlabel('Wavelength (nm)')
    plt.ylabel('Irradiance (uW/cm^2)')
    plt.xlim(350,1000)
    plt.ylim(0,14000)    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.grid()
    #plt.title(f"Irradiance Over Wavelength by Timestamp {timestamp} and Batch {batch_index}: \n Test Pattern {df3['Test']}")
    plt.title(f"Irradiance Over Wavelength for Backyard Readings {timestamp}: \n \n Test Pattern {df4['Test']}")

    
    
#timestamp_slider = widgets.IntSlider(value=0, min=0, max=len(df3) - 1, step=1, description='Timestamp Index')
timestamp_slider = widgets.IntSlider(value=0 , min=0, max=len(df3)-1 , step=1, description='Pattern#', continuous_update=True, orientation='horizontal')#,
    #readout=True)#,
    #readout_format='d')

#batch_slider = widgets.IntSlider(value=0, min=0, max=20, step=1, description='Batch Index')

# Create an interactive plot using widgets.interactive
interactive_plot = widgets.interactive(update_plot, timestamp_index=timestamp_slider, batch_index=batch_slider)

# Display the interactive plot
display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=0, description='Pattern#', max=86), Output()), _dom_classes=('widget-int…

# %%
def update_plot(timestamp_index):
    plt.figure(figsize=(12, 6))

    timestamp = timestamp_index

    wavelength_data_list = []
    irradiance_data_list = []
    
    for wavelength in wavelengths:
        wavelength_pattern = f'{wavelength}nm_(.*?)_irradiance_uW_per_cm_squared'
        wavelength_columns = [col for col in df4.columns if re.search(wavelength_pattern, col)]

        for column in wavelength_columns:
            color = 'black'  # Default color for wavelengths not explicitly defined

            # Check if the column exists before using it
            if column in df4.columns:
                # Extract wavelength data
                wavelength_data_str = wavelength
                try:
                    wavelength_data = int(wavelength_data_str)  # Convert string to integer
                except ValueError:
                    try:
                        wavelength_data = float(wavelength_data_str)  # Convert string to float
                    except ValueError:
                        continue  # Skip if wavelength cannot be converted to int or float

                # Append data to lists
                wavelength_data_list.append(wavelength_data)
                irradiance_data_list.append(df4[column][timestamp_index])
                
    # Plot data points
    plt.plot(wavelength_data_list, irradiance_data_list, linestyle='-', marker = 'o',markersize = 10, markeredgecolor = 'black', mfc = 'k', linewidth = 4,color='red')

   # Add background colors with low alpha
    plt.axvspan(350, 400, alpha=0.5, color='plum',label='Near UV from 300-400nm')
    plt.axvspan(400, 430, alpha=0.5, color='violet',label='Violet from 400-430nm ')
    plt.axvspan(430, 490, alpha=0.2, color='blue',label='Blue from 430-490nm')
    plt.axvspan(490, 530, alpha=0.2, color='green',label='Green from 490-530nm')
    plt.axvspan(530, 580, alpha=0.2, color='yellow',label='Yellow from 530-580nm')
    plt.axvspan(580, 630, alpha=0.2, color='orange',label='Orange from 580-630nm')
    plt.axvspan(630, 700, alpha=0.2, color='red',label='Red from 630-700nm')
    plt.axvspan(700, 1000, alpha=1, color='lavender',label='Near IR from 700-1,000nm')
            
    plt.xlabel('Wavelength (nm)')
    plt.ylabel('Irradiance (uW/cm^2)')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.xlim(350,1000)
    plt.ylim(0,14000)    
    plt.grid()
    plt.title(f"Irradiance Over Wavelength by Test Pattern {timestamp}: \n \n Test Pattern {df4['Test']}")

# Create a slider widget
timestamp_slider = widgets.IntSlider(value=0, min=0, max=len(df4) - 1, step=1, description='Timestamp Index')

# Create an interactive plot using widgets.interactive
interactive_plot = widgets.interactive(update_plot, timestamp_index=timestamp_slider)

# Display the interactive plot
display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=0, description='Timestamp Index', max=133), Output()), _dom_classes=('wi…

# %%
# Extract all unique wavelengths
wavelengths = sorted(set(re.findall(r'(\d+)nm_', ' '.join(df4.columns))))

# Function to update the plot based on selected timestamp
def update_plot(timestamp_index):
    plt.figure(figsize=(12, 6))

    timestamp = df4['timestamp_iso8601'][timestamp_index]

    for wavelength in wavelengths:
        wavelength_pattern = f'{wavelength}nm_(.*?)_irradiance_uW_per_cm_squared'
        wavelength_columns = [col for col in df4.columns if re.search(wavelength_pattern, col)]

        for column in wavelength_columns:
            color = re.search(wavelength_pattern, column).group(1)

            wavelength_data = df4[f'irradiance_{wavelength}nm_{color}_wavelength_nm']
            irradiance_data = df4[column]
            wavelength_uncertainty = df4[f'irradiance_{wavelength}nm_{color}_wavelength_uncertainty_nm']
            irradiance_uncertainty = df4[f'irradiance_{wavelength}nm_{color}_irradiance_uncertainty_uW_per_cm_squared']

            plt.errorbar(wavelength_data, irradiance_data, xerr=wavelength_uncertainty, yerr=irradiance_uncertainty,color=color,
                         label=f'{wavelength}nm - {color}', linestyle='', marker='o', markersize=3, capsize=3)

   # Add background colors with low alpha
    plt.axvspan(350, 400, alpha=0.5, color='plum',label='Near UV from 300-400nm')
    plt.axvspan(400, 430, alpha=0.5, color='violet',label='Violet from 400-430nm ')
    plt.axvspan(430, 490, alpha=0.2, color='blue',label='Blue from 430-490nm')
    plt.axvspan(490, 530, alpha=0.2, color='green',label='Green from 490-530nm')
    plt.axvspan(530, 580, alpha=0.2, color='yellow',label='Yellow from 530-580nm')
    plt.axvspan(580, 630, alpha=0.2, color='orange',label='Orange from 580-630nm')
    plt.axvspan(630, 700, alpha=0.2, color='red',label='Red from 630-700nm')
    plt.axvspan(700, 1000, alpha=1, color='lavender',label='Near IR from 700-1,000nm')
           
            
            
    plt.xlabel('Wavelength (nm)')
    plt.ylabel('Irradiance (uW/cm^2)')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.xlim(350,1000)
    plt.ylim(0,14000)    
 
    plt.grid()
    #plt.title(f'Irradiance Over Wavelength - {timestamp}')
    plt.title(f"Irradiance Over Wavelength for all Backyard Readings {timestamp_index}: \n \n Test Pattern {df4['Test']}")


# Create a slider widget
timestamp_slider = widgets.IntSlider(value=0, min=0, max=len(df3) - 1, step=1, description='Timestamp Index',disabled=True,)

# Create an interactive plot using widgets.interactive
interactive_plot = widgets.interactive(update_plot, timestamp_index=timestamp_slider)

# Display the interactive plot
display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=0, description='Timestamp Index', disabled=True, max=86), Output()), _do…

# %% [markdown]
# ## more to come ...
